# %% [markdown]
# <a href="https://colab.research.google.com/github/kwadwoasamoah/Assessment-of-proportion-of-succcess-of-MDG-No.7C-in-Sub-Saharan-Africa/blob/main/Asamoah_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code below is to import the csv file into google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ddd0dbd-fda7-453b-bd49-aa08e130207d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ddd0dbd-fda7-453b-bd49-aa08e130207d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final data for python projects.csv to final data for python projects.csv

# %%
#Initialising of the relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import io
df2 = pd.read_csv(io.BytesIO(uploaded['final data for python projects.csv']))

df2.head()
# Out:
#   CountryCode Country SeriesCode MDG  ... Type.29  2020  Footnotes.30 Type.30
# 0          24  Angola        665   Y  ...
# 1          24  Angola        666   N  ...
# 2          24  Angola        667   N  ...
# 3          24  Angola        668   Y  ...
# 4          24  Angola        669   N  ...
#
# [5 rows x 98 columns]

# %%
#Code below initiates functions to clean the data 
to_drop = ["CountryCode","SeriesCode","Footnotes","MDG","Footnotes.1","Footnotes.2","Footnotes.3","Footnotes.4","Footnotes.5","Footnotes.6","Footnotes.7","Footnotes.8","Footnotes.9","Footnotes.10","Footnotes.11","Footnotes.12","Footnotes.13","Footnotes.14","Footnotes.15","Footnotes.16","Footnotes.17","Footnotes.18","Footnotes.19","Footnotes.20","Footnotes.21","Footnotes.22","Footnotes.23","Footnotes.23","Footnotes.24","Footnotes.25","Footnotes.26","Footnotes.27","Footnotes.28","Footnotes.29","Footnotes.30","Type","Type.1","Type.2","Type.3","Type.4","Type.5","Type.6","Type.7","Type.8","Type.9","Type.10","Type.11","Type.12","Type.13","Type.14","Type.15","Type.16","Type.17","Type.18","Type.19","Type.20","Type.21","Type.22","Type.23","Type.24","Type.25","Type.26","Type.27","Type.28","Type.29","Type.30","2016","2017","2018","2019","2020"]

df2.drop(to_drop, inplace=True, axis=1)

df2.head()
# Out:
#   Country                                             Series  ...  2014  2015
# 0  Angola  Proportion of the population using improved dr...  ...  49.0  49.0
# 1  Angola  Proportion of the population using improved dr...  ...  75.0  75.0
# 2  Angola  Proportion of the population using improved dr...  ...  28.0  28.0
# 3  Angola  Proportion of the population using improved sa...  ...  51.0  52.0
# 4  Angola  Proportion of the population using improved sa...  ...  89.0  89.0
#
# [5 rows x 28 columns]

# %%
#Code below filters the data to show only a part of the data set we want to work on first
df3 = df2[df2.Series == "Proportion of the population using improved drinking water sources, total"]
df3
# Out:
#                               Country  ...   2015
# 0                              Angola  ...   49.0
# 6                               Benin  ...   78.0
# 12                           Botswana  ...   96.0
# 18                       Burkina Faso  ...   82.0
# 24                            Burundi  ...   76.0
# 30                           Cameroon  ...   76.0
# 36                         Cape Verde  ...   92.0
# 42           Central African Republic  ...   69.0
# 48                               Chad  ...   51.0
# 54                            Comoros  ...   90.0
# 60                              Congo  ...   77.0
# 66                      Cote d'Ivoire  ...   82.0
# 72   Democratic Republic of the Congo  ...   52.0
# 78                           Djibouti  ...   90.0
# 84                  Equatorial Guinea  ...   48.0
# 90                            Eritrea  ...   58.0
# 96                           Ethiopia  ...   57.0
# 102                             Gabon  ...   93.0
# ...

# %%
#Further cleaning of the dataset
to_drop2 = ["Series"]
df4 = df3.drop(to_drop2, inplace=True, axis=1)
df3
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Country  1990  1991  ...   2013   2014   2015
# 0                              Angola  46.0  46.0  ...   48.0   49.0   49.0
# 6                               Benin  57.0  58.0  ...   77.0   78.0   78.0
# 12                           Botswana  92.0  93.0  ...   96.0   96.0   96.0
# 18                       Burkina Faso  44.0  44.0  ...   82.0   82.0   82.0
# 24                            Burundi  69.0  69.0  ...   76.0   76.0   76.0
# 30                           Cameroon  51.0  52.0  ...   75.0   75.0   76.0
# 36                         Cape Verde   NaN   NaN  ...   91.0   92.0   92.0
# ...

# %%
#Further manipulation of the dataset to increase ease of work
df5 = df3.transpose()

df5
# Out:
#             0      6         12   ...                          276     282       288
# Country  Angola  Benin  Botswana  ...  United Republic of Tanzania  Zambia  Zimbabwe
# 1990         46     57        92  ...                           54      49        79
# 1991         46     58        93  ...                           54      50        80
# 1992         46     59        93  ...                           54      50        80
# 1993         46     60        93  ...                           54      50        80
# 1994         46     61        94  ...                           54      51        80
# 1995         46     62        94  ...                           54      51        80
# 1996         46     63        94  ...                           54      51        80
# 1997         46     63        94  ...                           54      52        80
# 1998         46     64        94  ...                           54      52        79
# ...

# %%
header_row = 0

df5.columns = df5.iloc[header_row]

df5.columns
# Out:
# Index(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon',
#        'Cape Verde', 'Central African Republic', 'Chad', 'Comoros', 'Congo',
#        'Cote d'Ivoire', 'Democratic Republic of the Congo', 'Djibouti',
#        'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar',
#        'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mayotte', 'Mozambique',
#        'Namibia', 'Niger', 'Nigeria', 'Reunion', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'Swaziland', 'Togo', 'Uganda',
#        'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country')

# %%
df5
# Out:
# Country  Angola  Benin  Botswana  ...  United Republic of Tanzania  Zambia  Zimbabwe
# Country  Angola  Benin  Botswana  ...  United Republic of Tanzania  Zambia  Zimbabwe
# 1990         46     57        92  ...                           54      49        79
# 1991         46     58        93  ...                           54      50        80
# 1992         46     59        93  ...                           54      50        80
# 1993         46     60        93  ...                           54      50        80
# 1994         46     61        94  ...                           54      51        80
# 1995         46     62        94  ...                           54      51        80
# 1996         46     63        94  ...                           54      51        80
# 1997         46     63        94  ...                           54      52        80
# 1998         46     64        94  ...                           54      52        79
# ...

# %%
df6= df5.drop(["Country"])

df6
# Out:
# Country Angola Benin Botswana  ... United Republic of Tanzania Zambia Zimbabwe
# 1990        46    57       92  ...                          54     49       79
# 1991        46    58       93  ...                          54     50       80
# 1992        46    59       93  ...                          54     50       80
# 1993        46    60       93  ...                          54     50       80
# 1994        46    61       94  ...                          54     51       80
# 1995        46    62       94  ...                          54     51       80
# 1996        46    63       94  ...                          54     51       80
# 1997        46    63       94  ...                          54     52       80
# 1998        46    64       94  ...                          54     52       79
# 1999        46    65       95  ...                          54     53       79
# 2000        46    66       95  ...                          54     53       79
# ...

# %%
#The code below checks that all NaN values are actually null 
df6['Cape Verde'].isnull()
# Out:
# 1990     True
# 1991     True
# 1992    False
# 1993    False
# 1994    False
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# 2000    False
# 2001    False
# 2002    False
# 2003    False
# 2004    False
# 2005    False
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# 2011    False
# 2012    False
# 2013    False
# 2014    False
# 2015    False
# Name: Cape Verde, dtype: bool

# %%
#The Code below determines the countries that were able to achieve access of >90% 
proportion_2015_overachievers = df6.iloc[-1] > 90

proportion_2015_overachievers
# Out:
# Country
# Angola                              False
# Benin                               False
# Botswana                             True
# Burkina Faso                        False
# Burundi                             False
# Cameroon                            False
# Cape Verde                           True
# Central African Republic            False
# Chad                                False
# Comoros                             False
# Congo                               False
# Cote d'Ivoire                       False
# Democratic Republic of the Congo    False
# Djibouti                            False
# Equatorial Guinea                   False
# Eritrea                             False
# Ethiopia                            False
# Gabon                                True
# Gambia                              False
# Ghana                               False
# Guinea                              False
# Guinea-Bissau                       False
# ...

# %%
#Visualisations of countries (Overachievers) that were able to achieve more than 90% access of the population
plot_Botswana = df6["Botswana"].plot()
plot_Cape_Verde = df6["Cape Verde"].plot()
plot_Gabon = df6["Gabon"].plot()
plot_Mauritius = df6["Mauritius"].plot()
plot_Namibia = df6["Namibia"].plot()
plot_Reunion = df6["Reunion"].plot()
plot_Sao_Tome_and_Principe = df6["Sao Tome and Principe"].plot()
plot_Seychelles = df6["Seychelles"].plot()
plot_South_Africa = df6["South Africa"].plot()

# Add title and axis names
plt.title('Over 90% access achieved')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
#The Code below determines the countries that were unable to achieve access of 50% of the population 
proportion_2015_underachievers = (df6.iloc[25,:]) < 50

proportion_2015_underachievers
# Out:
# Country
# Angola                               True
# Benin                               False
# Botswana                            False
# Burkina Faso                        False
# Burundi                             False
# Cameroon                            False
# Cape Verde                          False
# Central African Republic            False
# Chad                                False
# Comoros                             False
# Congo                               False
# Cote d'Ivoire                       False
# Democratic Republic of the Congo    False
# Djibouti                            False
# Equatorial Guinea                    True
# Eritrea                             False
# Ethiopia                            False
# Gabon                               False
# Gambia                              False
# Ghana                               False
# Guinea                              False
# Guinea-Bissau                       False
# ...

# %%
#Visualisations of countries (Underachievers) that were not able to achieve the goal of 50% access
plot_Angola = df6["Angola"].plot()
plot_Equatorial_Guinea = df6["Equatorial Guinea"].plot()

# Add title and axis names
plt.title('Under 50% access achieved')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
#The code below filters the data and enables visualistations for data on proportion of Urban poulation with access to improved drinking water in Sub-Saharan Africa

dg3 = df2[df2.Series == "Proportion of the population using improved drinking water sources, urban"]
dg3

#Further cleaning of the dataset
to_drop2 = ["Series"]
dg4 = dg3.drop(to_drop2, inplace=True, axis=1)
dg3

#Further manipulation of the dataset to increase ease of work
dg5 = dg3.transpose()

dg5

header_row = 0

dg5.columns = dg5.iloc[header_row]

dg5.columns

dg5

dg6= dg5.drop(["Country"])

dg6

#The code below checks that all NaN values are actually null 
dg6['Cape Verde'].isnull()

#The Code below determines the countries that were able to achieve access of >90% 
proportion_2015_overachievers_urban = dg6.iloc[-1] > 90

proportion_2015_overachievers_urban

#Visualisations of countries (Overachievers) that were able to achieve more than 90% access of the population

plot_Botswana = dg6["Botswana"].plot()
plot_Burkina_Faso = dg6["Burkina Faso"].plot()                       
plot_Burundi = dg6["Burundi"].plot()                        
plot_Cameroon = dg6["Cameroon"].plot()                           
plot_Cape_Verde = dg6["Cape Verde"].plot()                        
plot_Comoros = dg6["Comoros"].plot()                       
plot_Congo = dg6["Congo"].plot()                        
plot_Djibouti = dg6["Djibouti"].plot()                         
plot_Ethiopia = dg6["Ethiopia"].plot()                          
plot_Gabon = dg6["Gabon"].plot()                          
plot_Gambia = dg6["Gambia"].plot()                         
plot_Ghana = dg6["Ghana"].plot()                         
plot_Guinea = dg6["Guinea"].plot()                         
plot_Guinea_Bissau = dg6["Guinea-Bissau"].plot()                     
plot_Gabon = dg6["Gabon"].plot()
plot_Lesotho = dg6["Lesotho"].plot()                          
plot_Malawi = dg6["Malawi"].plot()                         
plot_Mali = dg6["Mali"].plot()                          
plot_Mauritius = dg6["Mauritius"].plot()                         
plot_Namibia = dg6["Namibia"].plot()                          
plot_Niger = dg6["Niger"].plot()                           
plot_Reunion = dg6["Reunion"].plot()
plot_Sao_Tome_and_Principe = dg6["Sao Tome and Principe"].plot()
plot_Senegal = dg6["Senegal"].plot()                  
plot_Seychelles = dg6["Seychelles"].plot()
plot_South_Africa = dg6["South Africa"].plot()
plot_Swaziland = dg6["Swaziland"].plot()                     
plot_Togo = dg6["Togo"].plot()                     
plot_Uganda = dg6["Uganda"].plot()                     
plot_Zimbabwe = dg6["Zimbabwe"].plot()                    


# Add title and axis names
plt.title('Over 90% access achieved (Urban)')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#The Code below determines the countries that were unable to achieve access of 50% of the population 
proportion_2015_underachievers_urban = (dg6.iloc[25,:]) < 50

proportion_2015_underachievers_urban

#Visualisations of countries (Underachievers) that were not able to achieve the goal of 50% access

# Add title and axis names
plt.title('Under 50% access achieved (Urban)')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
#The code below filters the data and enables visualistations for data on proportion of Rural poulation with access to improved drinking water in Sub-Saharan Africa

#Code below filters the data to show only a part of the data set we want to work on first
dh3 = df2[df2.Series == "Proportion of the population using improved drinking water sources, rural"]
dh3

#Further cleaning of the dataset
to_drop2 = ["Series"]
dh4 = dh3.drop(to_drop2, inplace=True, axis=1)
dh3

#Further manipulation of the dataset to increase ease of work
dh5 = dh3.transpose()

dh5

header_row = 0

dh5.columns = dh5.iloc[header_row]

dh5.columns

dh5

dh6= dh5.drop(["Country"])

dh6

#The code below checks that all NaN values are actually null 
dh6['Cape Verde'].isnull()

#The Code below determines the countries that were able to achieve access of >90% 
proportion_2015_overachievers_rural = dh6.iloc[-1] > 90

proportion_2015_overachievers_rural

#Visualisations of countries (Overachievers) that were able to achieve more than 90% access of the population
plot_Botswana = dh6["Botswana"].plot()
plot_Mauritius = dh6["Mauritius"].plot()
plot_Reunion = dh6["Reunion"].plot()
plot_Sao_Tome_and_Principe = dh6["Sao Tome and Principe"].plot()
plot_Seychelles = dh6["Seychelles"].plot()


# Add title and axis names
plt.title('Over 90% access achieved (Rural)')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#The Code below determines the countries that were unable to achieve access of 50% of the population 
proportion_2015_underachievers_rural = (dh6.iloc[25,:]) < 50

proportion_2015_underachievers_rural

#Visualisations of countries (Underachievers) that were not able to achieve the goal of 50% access
plot_Angola = dh6["Angola"].plot()
plot_Chad = dh6["Chad"].plot()                      
plot_Congo = dh6["Congo"].plot()                        
plot_Democratic_Republic_of_the_Congo = dh6["Democratic Republic of the Congo"].plot()                         
plot_Equatorial_Guinea = dh6["Equatorial Guinea"].plot()                          
plot_Ethiopia = dh6["Ethiopia"].plot()                          
plot_Madagascar = dh6["Madagascar"].plot()                         
plot_Mozambique = dh6["Mozambique"].plot()                         
plot_Niger = dh6["Niger"].plot()                         
plot_Sierra_Leone = dh6["Sierra Leone"].plot()                     
plot_Togo = dh6["Togo"].plot()
plot_United_Republic_of_Tanzania = dh6["United Republic of Tanzania"].plot()                          
 
# Add title and axis names
plt.title('Under 50% access achieved (Rural)')
plt.xlabel('Years')
plt.ylabel('Proportions')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
